# %% [markdown]
# # BPL IEC validation
#
# Author: Jan Peter Axelsson
#
# Here I try to reproduce somre results from Jonas Månssons master thesis report "Control of chromatography comlumn in production scale", TFRT-5599.
#
# The interaction withe the model has changed slightly so that linear flow rate LF = F/area is used. The column volume is now specified in terms of (cross-section) area times height. Thus by changing area the scale up works fine and what you do in practice. Further the time unit changed from seconds to minutes.
#
# The model has 5 states as listed below, 3 states in liquid mobile phase and 2 states for the gel for bound proteins. In a few of Jonas figures also bound ions of the buffer are plotted but I do not do that. Bound ions of the buffer can be calculated from the difference of total binding capaciety $Q_{av}$ and bound protein and bound protein antagonist, see section 5.1 in the report.
#
# The molecular weights listed below are not used in the simulations. They just give typical values and the molecular weight for bound protein and antagonist protein is just arbitrary here.
#
# Parameters of the model in general as well as time scale are all arbitrary and focus is on qualitative aspects of the model.
#
# The height of the column is 20 cm which is a common size in the industry.

# %%
run -i BPL_IEC_explore.py
# Out:
# Windows - run FMU pre-compiled JModelica 2.14
#
# Model for bioreactor has been setup. Key commands:
#  - par()       - change of parameters and initial values
#  - init()      - change initial values only
#  - simu()      - simulate and plot
#  - newplot()   - make a new plot
#  - show()      - show plot from previous simulation
#  - disp()      - display parameters and initial values from the last simulation
#  - describe()  - describe culture, broth, parameters, variables with values/units
#
# Note that both disp() and describe() takes values from the last simulation
#
# Brief information about a command by help(), eg help(simu)
# Key system information is listed with the command system_info()

# %%
 plt.rcParams['figure.figsize'] = [30/2.54, 24/2.54]

# %%
describe('chromatography'); print(); describe('liquidphase')
# Out:
# Ion exchange chromatorgraphy controlled with varying salt-concentration. The pH is kept constant.
#
# Chromatography liquidphase (or mobilephase) substances included in the model
#
# Protein                  - index =  1 - molecular weight =  22000.0 Da
# Antagonist protein       - index =  2 - molecular weight =  15000.0 Da
# Ion                      - index =  3 - molecular weight =  58.4 Da
# Protein bound            - index =  4 - molecular weight =  100000.0 Da
# Antagonist protein bound - index =  5 - molecular weight =  100000.0 Da
#
# Note that both proteins P and A as well as the salt-ion E is modelled to the same mobile phase volume.

# %% [markdown]
# ## Loading
#
# The parameter notation and values are the same as in the referred report. However the flow rate is here denoted F while q in the report. The column is diveded in n=8 sections and set at compilation time. The values are arbitrarly chosen in the report and the focus is on qualitative aspects of the model.
#
# The simplified model describe only the column in terms of volume and does not distinguish a high column with a small diameter from a lower with larger diameter.
#
# The parameters k1, k2, k3, k4 and Q_av are given relative volume and with increased column volume a larger capacity is thus obtained.

# %%
describe('column.n')
# Out:
# Number of sections of the column : 8

# %%
# Loading of the column - try to reproduce Jonas figure 13.
newplot(title='Adsorption along the column during loading', plotType='Loading') 

# Column properties 
par(LFR=12.0)
par(k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)
par(height=20, diameter=0.714)

# Operation
par(P_in=1.0, A_in=1.0, E_in=8)
par(scale_volume=False, stop_adsorption=50, start_desorption=150, stop_desorption=450)
par(start_pooling=220, stop_pooling=450)

# Simulation
simu(100)
# Out:
# Error - the following requirements do not hold:
# parDict['stationary_desorption'] < parDict['stop_desorption']
# Error - the following requirements do not hold:
# parDict['stationary_desorption'] < parDict['stop_desorption']
# ---------------------------------------------------------------------------
# FMUException                              Traceback (most recent call last)
# Cell In [5], line 15
#      12 par(start_pooling=220, stop_pooling=450)
#      14 # Simulation
# ---> 15 simu(100)
#
# File \\VBoxSvr\Modelica\GitHub\Colab\BPL_IEC_validation\BPL_IEC_explore.py:1156, in simu(simulationTimeLocal, mode, options, diagrams, timeDiscreteStates)
#    1154       model.set(parLocation[key],parDict[key])
#    1155    # Simulate
# -> 1156    sim_res = model.simulate(final_time=simulationTime, options=options)
#    1157    simulationDone = True
#    1158 elif mode in ['Continued', 'continued', 'cont']:
#
# File src\pyfmi\fmi.pyx:7453, in pyfmi.fmi.FMUModelCS2.simulate()
#
# ...

# %%
# We just check that we had the same volume flow rate as Jonas
describe('F')
# Out:
# Column volumetric flow rate : 0.08 [ mL/min ]

# %% [markdown]
# Looks like Figure 13 in Jonas report!

# %%
# Impact of shorter time for loading and then less material
newplot(title='Loading', plotType='Loading-combined')
show()

# Simulation with changed parameter t2
par(stop_adsorption=30); simu(100)

# Reset changed parameter
par(stop_adsorption=50)

# %% [markdown]
# To the left the inlet loading over time.
# To the right upper concentration along the column at different times and in steady states finally
# To the right lower concentrations along the colunn in steady state.
#
# We see that a shorter time and then less material makes less of the column capacity used.
#
# Note that the flow through the column is constant despite change from sample to just buffer 1, and shown in how the volume of the waste tank increase with time.

# %% [markdown]
# ## Elution

# %%
# Elution of the column
newplot(title='Elution peaks', plotType='Elution')

# Operation
par(P_in=1, A_in=1.0, E_in=8)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
simu(550)

# %% [markdown]
# Very close to Jonas Figure 14!
#
# The upper diagrams shows the column outlet concentrations of P and A over time.
#
# The lower diagram shows the sum (or possibly the UV signal) at column outlet as well as the salt concentration. We have some separation between the two peaks.
#
# Note that the salt concentration deviates slightly from the linear increse between time 50 to 100. This is due to ion interaction with P and A in the column. The ion-salt concentration is scaled with factor 0.05 to get comparable concentrations to P and A.
#
# I have here simulated time 150 of adsorbtion and then started elution. Here is time counted as zero at time of start of elutions. Not sure how long Jonas simulated to get steady state before he did elution.

# %%
# More complete visualization of the elution phase and the different flows
newplot(title='Elution and corresponding flows', plotType='Elution-combined')
show()

# Simulation with changed parameter t2
par(stop_adsorption=30); simu(550)

# Reset changed parameter
par(stop_adsorption=50)

# %% [markdown]
# Here a diagram that shows the peaks at the outlet as shown in the previous diagram. Below the flow rates of the three differnet sorces. Here time is 0 at start of adsorbtion and elution starts at time 150.
#
# All material goes at the end to the waste tank. Automatic pooling to a product tank is not implemented yet.
#
# The comparison with a smaller loading and no effect on the P and A peaks confuse me.

# %% [markdown]
# ## Change of resin property I
#
# Here parameter k4 is lowered by a factor 6. This means that protein P still binds more easily to the gel than protein A but protein A now binds more easily to the gel than before.

# %%
# Loading of the column - try to reproduce Jonas figure 15.
newplot(title='Adsorption along the column during loading - k4 changed', plotType='Loading') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.05, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0)
par(LFR=12.0, stop_adsorption=50)

# Simulation
simu(100)

# %% [markdown]
# This corresponds well to Jonas figure 15.
#
# The main impact of lowering parameter k4 is that concentration of bound A doubles.
# Also some P is not bound and therefore wasted.

# %%
# Elution of the column - try to reproduce figure 16
newplot(title='Elution peaks - parameter k4 is changed', plotType='Elution')

# Operation
par(P_in=1, A_in=1.0, E_in=8)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
simu(550)
ax2.set_ylim([0, 0.6])
plt.show()

# %% [markdown]
# Results correspond well to figure 16.
#
# Now we see no separation between the two components P and A in the chromatogram.

# %% [markdown]
# ## Change of resin property II

# %%
# Loading and elution of the column - try to reproduce Jonas figure 17.
newplot(title='Elution peaks - change of ratio k1/k2', plotType='Elution') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=0.0, E_in=8)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
par(k1=0.05, k2=0.50); simu(550)
par(k1=0.05, k2=0.25); simu(550)
par(k1=0.05, k2=0.05); simu(550)
par(k1=0.25, k2=0.05); simu(550)
par(k1=0.50, k2=0.05); simu(550)

# Adjust diagrams
ax1.set_ylim([0, 0.65])
ax2.set_ylim([0, 0.65])
plt.show()

# %% [markdown]
# The results are similar to figure 17.
#
# The sharpest peak (left) we have for k1/k2=0.1 and the broadest peak (right) for k1/k2=10.0-

# %% [markdown]
# ## When does superposition of chromatograms hold?

# %%
# Loading and elution of the column - try to reproduce Jonas figure 18.
newplot(title='Elution peaks - individual and combined - load 1.0 g/L each', plotType='Elution') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
par(P_in=1.0, A_in=1.0); simu(550)
par(P_in=1.0, A_in=0.0); simu(550)
par(P_in=0.0, A_in=1.0); simu(550)

# Adjust diagrams
ax1.set_ylim([0, 0.65])
ax2.set_ylim([0, 0.65])
plt.show()

# %% [markdown]
# We see that the sample with both P and A gives a chromatogram (solid line) that is different from what we would get from adding chromatograms for the individual runs (dashed and dottet line).
#
# The main reason is that the high load of the column makes the response to A very different when run individually.
#
# In this case with high load on the column superposition does not hold.

# %%
# Now contiune with a much lower load - try to reproduce Jonas figure 18.
newplot(title='Elution peaks - individual and combined - load 0.1 g/L each', plotType='Elution') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
par(P_in=0.1, A_in=0.1); simu(550)
par(P_in=0.1, A_in=0.0); simu(550)
par(P_in=0.0, A_in=0.1); simu(550)

# Adjust diagrams
#ax1.set_ylim([0, 0.65])
#ax2.set_ylim([0, 0.65])
plt.show()

# %% [markdown]
# We now see with this lower load that chromatogram can be seen as a superposition of the chromatograms for the individual components. Result the same as figure 18.

# %% [markdown]
# ## Change time length and concentration of loading

# %%
# Elution of the column
newplot(title='Elution peaks - different loading time', plotType='Elution')

# Column properties as before
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0, E_in=8)
par(LFR=12.0, stop_adsorption=100, start_desorption=150, stop_desorption=450)

# Simulation
par(stop_adsorption=100); simu(550)
par(stop_adsorption=25);  simu(550)

# Adjust diagrams
ax1.set_ylim([0, 0.65])
ax2.set_ylim([0, 0.65])

# Reset paramter to default
par(t_stop_loading=50)
plt.show()
# Out:
# Error: t_stop_loading - seems not an accessible parameter - check the spelling

# %%
# Elution of the column
newplot(title='Elution peaks - different loading concentration', plotType='Elution')

# Column properties as before
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0, E_in=8)
par(LFR=12.0, stop_adsorption=100, start_desorption=150, stop_desorption=450)

# Simulation
par(P_in=1.0, A_in=1.0, stop_adsorption=100); simu(550)
par(P_in=0.1, A_in=0.1, stop_adsorption=100); simu(550)

# Adjust diagrams
ax1.set_ylim([0, 0.65])
ax2.set_ylim([0, 0.65])

# Reset paramter to default
par(P_in=1.0, A_in=1.0, stop_adsorption=50)
plt.show()

# %% [markdown]
# The results are similar to Jonas figure 19.
#
# A difference is that here the column is regarded as in steady state after time 150 (i.e. 0 in the time scale above), but we see there is still a small transient and $c[P]$ and $c[A]$ are reaching zero around time 170 (i.e. 20 in the time scale above). This does not affect the overall results much, though.

# %% [markdown]
# ## Changing slope of the elution gradient
#
# Here we only study protein P and let concentration of A be zero.

# %%
# Elution of the column
newplot(title='Elution peaks - different elution gradients', plotType='Elution')

# Column properties as before
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0, E_in=8)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)

# Simulation
simu(550)
par(stop_desorption=300); simu(550)
par(stop_desorption=600); simu(550)

# Adjust diagrams
ax1.set_ylim([0, 0.55])
ax2.set_ylim([0, 0.55])

# Reset paramter to default
par(stop_desorption=450)
plt.show()

# %% [markdown]
# The results are similar to Jonas figure 20.
#
# A longer less steep gradient gives somewhat better separation of peaks. The prize is longer processing time, though.

# %% [markdown]
# ## Pooling
# We test pooling of product based on given times, i.e. without feedback from UV.
# The material goes to tank_waste except during time for pooling when it goes to tank_harvest.
# Start with the settings of the first example.
#
# The simulations below are not found in Jonas report but natural to investigate a bit.

# %%
# Loading and elution as for the very first example and now with pooling at the outlet
newplot(title='Elution and pooling', plotType='Elution-pooling') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)
par(start_pooling=(150+80), stop_pooling=(150+300))

# Simulation
simu(550)

plt.show()

# %%
# And how material is accumulated in harvest and waste tanks, respectively
newplot(title='Pooling to tank harvest and waste', plotType='Pooling'); show()

# %%
# Quality of the harvested product
print(model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))

# Efficiency of collecting the protein of interest calculated below
print(model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))
# Out:
# [0.98171229]
# [0.94830911]

# %% [markdown]
# We have a quality of 98% and an efficiency of about 95 percent and looks good!
#
# Note, that a small shift in the prescribed pooling intervall will change both quality and the efficiency as seen below.

# %%
# Loading and elution as above but now compared with a small shift of pooling
newplot(title='Elution and pooling', plotType='Pooling') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)
par(start_pooling=(150+80), stop_pooling=(150+300))

# Simulations
simu(550)

par(start_pooling=(150+90)); simu(550)

# %%
# Quality of the harvested product
print('quality =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))

# Efficiency of collecting the protein of interest calculated below
print('efficency =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))
# Out:
# quality = [0.99423901]
# efficency = [0.92556606]

# %% [markdown]
# As we change the pooling to start later, the product quality will increase but the efficiency of the separation process goes down.

# %% [markdown]
# ## Pooling and impact of changes in the column resin on results

# %%
# Loading, elution and fixed time for pooling and impact of changed resin 
newplot(title='Elution and pooling', plotType='Elution-pooling') 

# Column properties 
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.3, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)
par(start_pooling=(150+80), stop_pooling=(150+300))

# Simulations
simu(550)
print('quality 1 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))
print('efficency 1 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))

par(k4=0.2); simu(550)
print('quality 2 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))
print('efficency 2 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))
# Out:
# quality 1 = [0.98171229]
# efficency 1 = [0.94830911]
# quality 2 = [0.94805582]
# efficency 2 = [0.94250103]

# %% [markdown]
# We see that a change in the resin property affect quality(and also efficency, not shown). The best would be to adapt the pooling limits to the chromatogram, i.e. use feedback control of measured UV-signal.

# %%
# Loading, elution and fixed time for pooling and impact of changed resin 
newplot(title='Elution and pooling', plotType='Elution-pooling') 

# Column properties - and now k4 remains changed
par(diameter=0.714, k1=0.3, k2=0.05, k3=0.05, k4=0.2, Q_av=3.0)

# Operation
par(P_in=1, A_in=1.0)
par(LFR=12.0, stop_adsorption=50, start_desorption=150, stop_desorption=450)
par(start_pooling=(150+80), stop_pooling=(150+300))

# Simulations - compare t_start_pool fixed and adjusted 
simu(550)
print('quality 1 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))
print('efficency 1 =',model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))

par(t_start_pooling=(150+92)/60)
simu(550)
print('quality 1 =', model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_harvest.m[2]')))
print('efficency 2 =', model.get('tank_harvest.m[1]')/(model.get('tank_harvest.m[1]') + model.get('tank_waste.m[1]')))
# Out:
# quality 1 = [0.94805582]
# efficency 1 = [0.94250103]
# Error: t_start_pooling - seems not an accessible parameter - check the spelling
# quality 1 = [0.94805582]
# efficency 2 = [0.94250103]

# %% [markdown]
# So by start pooling after the chromatogram has passed the local minima and use that as a control principle, we in this example decrease the impact of resin degradation on product quality. The price is lowered efficency, though.

# %% [markdown]
# ## Decrease impact of resin degradation using feedback control
#
# The idea of start pooling after the chromatogram has passed the local minima can be automated and tested in this section. The idea is to simply measure the UV on-line and open and close the valve for pooling. The key problem is to translate the idea of identify the local mininima in a robust way. In this example here is no measurement noise and we implement a rudiementary controller and just reproduce the results from previous section and check also impact of larger resin degradation.
#
# In practice, a routine similar like this one is often used. The actual guarantee of preserving quality this way must be investigated experimentally.

# %% [markdown]
# ## System setup

# %%
describe('parts')
# Out:
# ['ackF', 'column', 'conductivity_detector', 'control_buffer2', 'control_pooling', 'control_sample', 'F', 'fluid_switch', 'liquidphase', 'MSL', 'scale_volume', 'scaling', 'tank_buffer1', 'tank_buffer2', 'tank_harvest', 'tank_mixing', 'tank_sample', 'tank_waste', 'u', 'uv_detector']

# %%
describe('MSL')
# Out:
# MSL: 3.2.2 build 3 - used components: RealInput, RealOutput, CombiTimeTable, Types

# %%
system_info()
# Out:
# System information
#  -OS: Windows
#  -Python: 3.10.6
#  -Scipy: not installed in the notebook
#  -PyFMI: 2.9.8
#  -FMU by: JModelica.org
#  -FMI: 2.0
#  -Type: FMUModelCS2
#  -Name: BPL_IEC.Column_system
#  -Generated: 2022-11-11T14:18:42
#  -MSL: 3.2.2 build 3
#  -Description: Bioprocess Library version 2.1.0
#  -Interaction: FMU-explore ver 0.9.5

# %%
model.get('Customer.contact_person')
# Out:
# ['Karl Johan Brink']
